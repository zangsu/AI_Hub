# %% [markdown]
# ## 미국 수화 알파벳에는 26개의 문자가 포함되어 있습니다. 이 중 두 개의 문자(j 및 z)에는 동작이 요구되므로 트레이닝 데이터세트에 포함되지 않았습니다.

# %% [markdown]
# ![스크린샷 2022-07-05 17.53.58.png](data:image/png;base64,...)

# %% [markdown]
# ## Data 로드

# %%
import pandas as pd

# %%
# train_df = pd.read_csv("sign_mnist_train.csv")
# valid_df = pd.read_csv("sign_mnist_valid.csv")

# %%
asl_path = "/content/drive/My Drive/datasets/asl/"

# %%
train_df = pd.read_csv(asl_path+"sign_mnist_train.csv")
valid_df = pd.read_csv(asl_path+"sign_mnist_valid.csv")

# %%
train_df.head()
# Out:
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0      3     107     118     127     134     139     143     146     150
# 1      6     155     157     156     156     156     157     156     158
# 2      2     187     188     188     187     187     186     187     188
# 3      2     211     211     212     212     211     210     211     210
# 4     12     164     167     170     172     176     179     180     184
#
#    pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0     153  ...       207       207       207       207       206       206
# 1     158  ...        69       149       128        87        94       163
# 2     187  ...       202       201       200       199       198       199
# 3     210  ...       235       234       233       231       230       226
# 4     185  ...        92       105       105       108       133       163
#
#    pixel781  pixel782  pixel783  pixel784
# 0       206       204       203       202
# 1       175       103       135       149
# 2       198       195       194       195
# 3       225       222       229       163
# 4       157       163       164       179
#
# [5 rows x 785 columns]

# %%
train_df.describe()
# Out:
#               label        pixel1        pixel2        pixel3        pixel4  \
# count  27455.000000  27455.000000  27455.000000  27455.000000  27455.000000
# mean      11.679476    145.419377    148.500273    151.247714    153.546531
# std        6.880558     41.358555     39.942152     39.056286     38.595247
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        6.000000    121.000000    126.000000    130.000000    133.000000
# 50%       12.000000    150.000000    153.000000    156.000000    158.000000
# 75%       18.000000    174.000000    176.000000    178.000000    179.000000
# max       23.000000    255.000000    255.000000    255.000000    255.000000
#
#              pixel5        pixel6        pixel7        pixel8        pixel9  \
# count  27455.000000  27455.000000  27455.000000  27455.000000  27455.000000
# mean     156.210891    158.411255    160.472154    162.339683    163.954799
# std       37.111165     36.125579     35.016392     33.661998     32.651607
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      137.000000    140.000000    142.000000    144.000000    146.000000
# 50%      160.000000    162.000000    164.000000    165.000000    166.000000
# 75%      181.000000    182.000000    183.000000    184.000000    185.000000
# max      255.000000    255.000000    255.000000    255.000000    255.000000
#
#        ...      pixel775      pixel776      pixel777      pixel778  \
# count  ...  27455.000000  27455.000000  27455.000000  27455.000000
# mean   ...    141.104863    147.495611    153.325806    159.125332
# std    ...     63.751194     65.512894     64.427412     63.708507
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...     92.000000     96.000000    103.000000    112.000000
# 50%    ...    144.000000    162.000000    172.000000    180.000000
# 75%    ...    196.000000    202.000000    205.000000    207.000000
# max    ...    255.000000    255.000000    255.000000    255.000000
#
#            pixel779      pixel780      pixel781      pixel782      pixel783  \
# count  27455.000000  27455.000000  27455.000000  27455.000000  27455.000000
# mean     161.969259    162.736696    162.906137    161.966454    161.137898
# std       63.738316     63.444008     63.509210     63.298721     63.610415
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      120.000000    125.000000    128.000000    128.000000    128.000000
# 50%      183.000000    184.000000    184.000000    182.000000    182.000000
# 75%      208.000000    207.000000    207.000000    206.000000    204.000000
# max      255.000000    255.000000    255.000000    255.000000    255.000000
#
#            pixel784
# count  27455.000000
# mean     159.824731
# std       64.396846
# min        0.000000
# 25%      125.500000
# 50%      182.000000
# 75%      204.000000
# max      255.000000
#
# [8 rows x 785 columns]

# %%
# target 분리
y_train = train_df['label']
y_valid = valid_df['label']

# %%
del train_df['label']
del valid_df['label']

# %%
x_train = train_df.values
x_valid = valid_df.values

# %%
print(x_train.shape, x_valid.shape)
# Out:
# (27455, 784) (7172, 784)

# %%
x_train2d = x_train.reshape(-1, 28, 28)
x_valid2d = x_valid.reshape(-1, 28, 28)
print(x_train2d.shape, x_valid2d.shape)
# Out:
# (27455, 28, 28) (7172, 28, 28)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(40,40))

num_images = 20
for i in range(num_images):
    row = x_train[i]
    label = y_train[i]
    
    image = row.reshape(28,28)
    plt.subplot(1, num_images, i+1)
    plt.title(label, fontdict={'fontsize': 30})
    plt.axis('off')
    plt.imshow(image, cmap='gray')

# %%
fig, ax = plt.subplots(nrows=5, ncols=5, figsize=(10, 10))
fig.tight_layout()
for i in range(5*5):
    image = x_train2d[i]
    label = y_train[i]
    ax.flatten()[i].set_title(label, fontdict={'fontsize': 20})
    
    ax.flatten()[i].imshow(image, cmap='gray')
    # ax.flatten()[i].axis('off')
plt.show()

# %%
x_train = x_train / 255
x_valid = x_valid / 255

# %%
x_train = x_train.reshape(-1,28,28,1)
x_valid = x_valid.reshape(-1,28,28,1)

# %%
import tensorflow.keras as keras

# %%
num_classes=24

# %%
# TODO: Categorically encode y_train and y_valid.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_valid = keras.utils.to_categorical(y_valid, num_classes)

# %% [markdown]
# ## Data Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
datagen = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip = True,
    vertical_flip = False,
)

# %%
import numpy as np

# %%
batch_size = 32
img_iter = datagen.flow(x_train, y_train, batch_size=batch_size)

x, y = img_iter.next()
fig, ax = plt.subplots(nrows=4, ncols=8)
for i in range(batch_size):
  image = x[i]
  image = np.squeeze(image)
  ax.flatten()[i].imshow(image)
plt.show()

# %%
datagen.fit(x_train)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Dense, Conv2D,
    MaxPool2D,
    Flatten,
    Dropout,
    BatchNormalization)

# %%
model = Sequential()
model.add(Conv2D(75, (3, 3), strides=1, padding="same", activation="relu", 
                 input_shape=(28, 28, 1)))
model.add(BatchNormalization())
model.add(MaxPool2D((2, 2), strides=2, padding="same"))
model.add(Conv2D(50, (3, 3), strides=1, padding="same", activation="relu"))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(MaxPool2D((2, 2), strides=2, padding="same"))
model.add(Conv2D(25, (3, 3), strides=1, padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(MaxPool2D((2, 2), strides=2, padding="same"))
model.add(Flatten())
model.add(Dense(units=512, activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(units=num_classes, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 75)        750
#
#  batch_normalization (BatchN  (None, 28, 28, 75)       300
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 75)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 50)        33800
#
#  dropout (Dropout)           (None, 14, 14, 50)        0
#
#  batch_normalization_1 (Batc  (None, 14, 14, 50)       200
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 50)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 25)          11275
#
#  batch_normalization_2 (Batc  (None, 7, 7, 25)         100
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 25)         0
#  2D)
#
#  flatten (Flatten)           (None, 400)               0
#
#  dense (Dense)               (None, 512)               205312
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 24)                12312
#
# =================================================================
# Total params: 264,049
# Trainable params: 263,749
# Non-trainable params: 300
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(img_iter,  epochs=20, 
          steps_per_epoch=len(x_train)/batch_size,
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/20
# 857/857 [==============================] - 14s 14ms/step - loss: 1.1090 - accuracy: 0.6448 - val_loss: 0.3202 - val_accuracy: 0.8699
# Epoch 2/20
# 857/857 [==============================] - 12s 14ms/step - loss: 0.3150 - accuracy: 0.8939 - val_loss: 0.4386 - val_accuracy: 0.8571
# Epoch 3/20
# 857/857 [==============================] - 12s 14ms/step - loss: 0.1903 - accuracy: 0.9356 - val_loss: 0.2152 - val_accuracy: 0.9265
# Epoch 4/20
# 857/857 [==============================] - 13s 15ms/step - loss: 0.1472 - accuracy: 0.9517 - val_loss: 0.0984 - val_accuracy: 0.9728
# Epoch 5/20
# 857/857 [==============================] - 12s 14ms/step - loss: 0.1191 - accuracy: 0.9607 - val_loss: 0.0910 - val_accuracy: 0.9650
# Epoch 6/20
# 857/857 [==============================] - 12s 14ms/step - loss: 0.1083 - accuracy: 0.9655 - val_loss: 0.0480 - val_accuracy: 0.9865
# Epoch 7/20
# 857/857 [==============================] - 11s 13ms/step - loss: 0.0928 - accuracy: 0.9709 - val_loss: 0.2612 - val_accuracy: 0.9304
# Epoch 8/20
# 857/857 [==============================] - 11s 13ms/step - loss: 0.0832 - accuracy: 0.9741 - val_loss: 0.1533 - val_accuracy: 0.9439
# Epoch 9/20
# 857/857 [==============================] - 11s 13ms/step - loss: 0.0823 - accuracy: 0.9751 - val_loss: 0.0457 - val_accuracy: 0.9847
# Epoch 10/20
# 857/857 [==============================] - 12s 14ms/step - loss: 0.0725 - accuracy: 0.9783 - val_loss: 0.3297 - val_accuracy: 0.9184
# Epoch 11/20
# 857/857 [==============================] - 12s 14ms/step - loss: 0.0730 - accuracy: 0.9789 - val_loss: 0.2529 - val_accuracy: 0.9258
# Epoch 12/20
# 857/857 [==============================] - 11s 13ms/step - loss: 0.0661 - accuracy: 0.9802 - val_loss: 0.1934 - val_accuracy: 0.9387
# Epoch 13/20
# 857/857 [==============================] - 11s 13ms/step - loss: 0.0650 - accuracy: 0.9819 - val_loss: 0.0375 - val_accuracy: 0.9891
# Epoch 14/20
# 857/857 [==============================] - 12s 14ms/step - loss: 0.0611 - accuracy: 0.9826 - val_loss: 0.0612 - val_accuracy: 0.9792
# Epoch 15/20
# 857/857 [==============================] - 12s 13ms/step - loss: 0.0625 - accuracy: 0.9823 - val_loss: 0.0377 - val_accuracy: 0.9854
# Epoch 16/20
# 857/857 [==============================] - 12s 14ms/step - loss: 0.0576 - accuracy: 0.9844 - val_loss: 0.0496 - val_accuracy: 0.9849
# Epoch 17/20
# 857/857 [==============================] - 13s 15ms/step - loss: 0.0546 - accuracy: 0.9846 - val_loss: 0.0087 - val_accuracy: 0.9975
# Epoch 18/20
# 857/857 [==============================] - 12s 14ms/step - loss: 0.0596 - accuracy: 0.9844 - val_loss: 0.3481 - val_accuracy: 0.9251
# Epoch 19/20
# 857/857 [==============================] - 12s 14ms/step - loss: 0.0513 - accuracy: 0.9856 - val_loss: 0.1769 - val_accuracy: 0.9703
# Epoch 20/20
# 657/857 [=====================>........] - ETA: 2s - loss: 0.0561 - accuracy: 0.9853

# %%
prob = model.predict(x_valid[:10])

# %%
import numpy as np

# %%
pred = np.argmax(prob, axis=1)
y = np.argmax(y_valid[:10], axis=1)
print(pred)
print(y)
