# %% [markdown]
# ## 미국 수화 알파벳에는 26개의 문자가 포함되어 있습니다. 이 중 두 개의 문자(j 및 z)에는 동작이 요구되므로 트레이닝 데이터세트에 포함되지 않았습니다.

# %% [markdown]
# ![스크린샷 2022-07-05 17.53.58.png](data:image/png;base64,...)

# %% [markdown]
# ## Data 로드

# %%
import pandas as pd
