# %% [markdown]
# ![인공지능-min.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # 신경망(Neural Network)
#
# ![스크린샷 2021-06-21 오전 8.26.31.png](data:image/png;base64,...)

# %% [markdown]
# ## 퍼셉트론(Perceptron)
# ![image.png](data:image/png;base64,...)
#
# * 다수의 신호를 입력받아 하나의 신호를 출력
# * 퍼셉트론은 신호 1, 0 값을 가짐
# * 활성 상태일때는 1, 비활성 상태일때는 0을 출력
# * 입력이 2개인 퍼셉트론
# * x1, x2 는 입력신호
# * y는 출력 신호
# * w1과  w2는 가중치
# * $y = w_1x_1 + w_2x_2$

# %% [markdown]
# ![스크린샷 2021-06-21 오전 8.56.24.png](data:image/png;base64,...)

# %% [markdown]
# * w는 입력신호(x) 가 결과에 주는 영향력을 조절하는 변수
# * 편향은 뉴런이 얼마나 쉽게 활성화 (결과로 1을 출력) 하느냐를 조정하는 매개변수
# * 편향의 값이 -10 이면 sum(입력 신호 * 가중치) 값이 10이 넘어야 활성화 된다는 의미

# %% [markdown]
# ## $$y = w_1x_1 + w_2x_2 + b$$
#
# ## $$ y =  \left[
# \begin{matrix}
#     x_1 & x_2 \\
# \end{matrix}
# \right]
# \left[
# \begin{matrix}
#     w_{1} \\
#     w_{2} \\
# \end{matrix}
# \right] + b $$

# %% [markdown]
# ![스크린샷 2021-07-10 오후 5.10.40.png](data:image/png;base64,...)

# %%
import numpy as np

# %% [markdown]
# ![스크린샷 2021-07-10 오후 1.30.33.png](data:image/png;base64,...)

# %% [markdown]
# # 신경망

# %% [markdown]
# ![3nn.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2021-07-10 오후 2.14.52.png](data:image/png;base64,...)

# %% [markdown]
# ## $$a_1 = w_{11}x_1 + w_{12}x_2 + b_1$$
#
# ## $$a_2 = w_{21}x_1 + w_{22}x_2 + b_2$$
#
# ## $$a_3 = w_{31}x_1 + w_{32}x_2 + b_3$$
#
#
# ## $$ \left[
# \begin{matrix}
#     a_1 & a_2 & a_3 \\
# \end{matrix}
# \right] =  \left[
# \begin{matrix}
#     x_1 & x_2 \\
# \end{matrix}
# \right]
# \left[
# \begin{matrix}
#     w_{11} & w_{21} & w_{31} \\
#     w_{12} & w_{22} & w_{32} \\
# \end{matrix}
# \right] + \left[
# \begin{matrix}
#     b_1 & b_2 & b_3 \\
# \end{matrix}
# \right] $$
