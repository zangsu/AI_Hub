# %% [markdown]
# # 주성분 분석

# %% [markdown]
# ![스크린샷 2021-05-11 오전 9.07.51.png](data:image/png;base64,...)

# %% [markdown]
# ## PCA 클래스

# %% [markdown]
# ## 원본 데이터 재구성

# %% [markdown]
# ## 설명된 분산
