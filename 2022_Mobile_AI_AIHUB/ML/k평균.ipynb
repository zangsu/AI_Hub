# %% [markdown]
# # k-평균 알고리즘
# ![스크린샷 2021-05-06 오전 11.12.07.png](data:image/png;base64,...)
#
# 1. 무작위로 k개의 클러스터 중심을 지정
# 2. 각 샘플에서 가장 가까운 클러스터 중심을 찾아 해당 클러스터의 샘플로 지정
# 3. 클러스터에 속한 샘플의 평균값으로 클러스터 중심을 변경
# 4. 클러스터 중심에 변화가 없을 때까지 2번으로 돌아가 반복

# %% [markdown]
# ## KMeans 클래스

# %% [markdown]
# # 클러스터 중심

# %% [markdown]
# ## 최적의 k 찾기
