# %% [markdown]
# # Wine Data

# %% [markdown]
# # 검증세트

# %% [markdown]
# ![스크린샷 2021-05-03 오후 1.34.47.png](data:image/png;base64,...)

# %% [markdown]
# # 교차 검증

# %% [markdown]
# ![스크린샷 2021-05-03 오후 1.34.57.png](data:image/png;base64,...)

# %% [markdown]
# # 하이퍼파라미터 튜닝

# %% [markdown]
# ## 랜덤 서치
#
# - randint : 두 정수 사이의 랜덤한 정수를 균등분포로 뽑아줌
# - uniform : 두 수 사이의 랜덤한 소수를 균등분포로 뽑아줌
