# %% [markdown]
# #Fashin MNIST
# Fashion Mnist는 옷, 바지 등 10가지 종류의 의류로 구성된 데이터입니다. 이 데이터는 (28, 28) 크기로 구성되어 있으며 Training Set 6만장, Test Set 1만장으로 총합 7만장으로 이루어져 있습니다. Keras에서 dataset을 import 할 수 있고, 처음 import 시 다운로드 하는 과정이 추가됩니다.
#
# ![008-696x279.png](data:image/png;base64,...)

# %%
from tensorflow.keras import datasets, layers, models, utils
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #모델구성

# %% [markdown]
# ![img1.daumcdn-5.png](data:image/png;base64,...)

# %% [markdown]
# #Drop out
# ![2409B53C58E10E2633.png](data:image/png;base64,...)

# %% [markdown]
# #Callback
